# %%
# %pip install transformers
# %pip install torch
# Out:
# Requirement already satisfied: transformers in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (4.36.2)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from transformers) (0.20.1)
# Requirement already satisfied: numpy>=1.17 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from transformers) (1.26.2)
# Requirement already satisfied: packaging>=20.0 in /Users/rprus/Library/Python/3.10/lib/python/site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from transformers) (2021.11.10)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.12.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->transformers) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->transformers) (2023.11.17)
# Requirement already satisfied: torch in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (2.1.2)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torch) (3.0.3)
# Requirement already satisfied: fsspec in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torch) (2023.12.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from sympy->torch) (1.3.0)

# %%
import numpy as np
import pandas as pd
from transformers import AutoModelForSequenceClassification, AutoTokenizer, pipeline

data = pd.read_csv('PSE_ISR-filtered_data.csv')

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer, pipeline

model_name = "bhadresh-savani/distilbert-base-uncased-emotion"
model = AutoModelForSequenceClassification.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name, truncation=True)
max_length = 256

# Change here: Set device to 'cpu'
sentiment_pipeline = pipeline(task="sentiment-analysis",
                              model=model,
                              tokenizer=tokenizer,
                              device=-1,  # Changed from 0 to -1 to use CPU
                              max_length=max_length)

# %%
threshold_strongly_pro_palestine = 0.7
threshold_pro_palestine = 0.6
threshold_neutral = 0.5
threshold_pro_israel = 0.4
threshold_strongly_pro_israel = 0.3

# %%
predicted_labels = []
batch_size = 100
total_records = len(data)
start_index = 0

while start_index < total_records:
    end_index = start_index + batch_size
    batch_data = data['self_text'][start_index:end_index]
    results = sentiment_pipeline([str(i) for i in batch_data])

    for result in results:
        score = result['score']
        if score >= threshold_strongly_pro_palestine:
            predicted_labels.append("strongly pro-Palestine")
        elif score >= threshold_pro_palestine:
            predicted_labels.append("pro-Palestine")
        elif score >= threshold_neutral:
            predicted_labels.append("neutral")
        elif score >= threshold_pro_israel:
            predicted_labels.append("pro-Israel")
        else:
            predicted_labels.append("strongly pro-Israel")

    start_index = end_index
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.

# %%
data['predicted_label'] = predicted_labels

for txt, pred_label, rslt in zip(data['self_text'], predicted_labels, results):
    print(f'Text: "{txt}"\nPredicted Label: {pred_label}\nScore: {rslt["score"]}\n{"-" * 40}')

data.to_csv('predicted-dateset.csv', index=False)
# Out:
# Text: "care belgium crack violent settler israel honest question hope answer"
# Predicted Label: strongly pro-Palestine
# Score: 0.5105515122413635
# ----------------------------------------
# Text: "talking palestinian killed year"
# Predicted Label: strongly pro-Palestine
# Score: 0.5708707571029663
# ----------------------------------------
# Text: "totally fascist regime nazi shit germany"
# Predicted Label: strongly pro-Palestine
# Score: 0.9894216656684875
# ----------------------------------------
# Text: "attack mention responsible caught killed howard happened guess settler blood lust israeli government support refuse hold accountable free innocent people"
# Predicted Label: neutral
# Score: 0.7417247295379639
# ----------------------------------------
# Text: "palestine water country outsized power stage rely national gas supply economy"
# Predicted Label: pro-Palestine
# Score: 0.5722042322158813
# ----------------------------------------
# Text: "hegemony"
# Predicted Label: strongly pro-Palestine
# Score: 0.9304496049880981
# ----------------------------------------
# Text: "buddy tripping month high"
# Predicted Label: pro-Israel
# Score: 0.7293893098831177
# ----------------------------------------
# Text: "seek destruction"
# Predicted Label: pro-Palestine
# Score: 0.7712485790252686
# ----------------------------------------
# Text: "gaza exist egypt"
# Predicted Label: pro-Israel
# Score: 0.5040600299835205
# ----------------------------------------
# Text: "amp nazi germany"
# Predicted Label: strongly pro-Palestine
# Score: 0.7769736051559448
# ----------------------------------------
# Text: "nan"
# Predicted Label: neutral
# Score: 0.7808733582496643
# ----------------------------------------
# Text: "worked hamas decade"
# Predicted Label: pro-Israel
# Score: 0.6883288025856018
# ----------------------------------------
# Text: "kid hero allowed heart hope incredible historical footage tym sharing long love resistance palestine free"
# Predicted Label: strongly pro-Palestine
# Score: 0.847088634967804
# ----------------------------------------
# Text: "age atheist guy dawkins harris kitchens western chauvinist islamophobia racist listen middle school thankfully listening shit support military bombing campaign muslim arab country"
# Predicted Label: strongly pro-Palestine
# Score: 0.6613633036613464
# ----------------------------------------
# Text: "headline"
# Predicted Label: pro-Israel
# Score: 0.5040600299835205
# ----------------------------------------
# Text: "constant suicide bomber religious extremist"
# Predicted Label: strongly pro-Palestine
# Score: 0.9891947507858276
# ----------------------------------------
# Text: "sooo concentration camp bad lesson israel holocaust"
# Predicted Label: pro-Palestine
# Score: 0.5040600299835205
# ----------------------------------------
# Text: "source biased label hamas terrorist"
# Predicted Label: strongly pro-Palestine
# Score: 0.5040600299835205
# ----------------------------------------
# Text: "fuck innocent people dying justify portraying palestinian rape loving terrorist hope sens incredibly racist ideology nazi"
# Predicted Label: strongly pro-Palestine
# Score: 0.5842249393463135
# ----------------------------------------
# Text: "stuff teenager tbe drug joke lift psychologically pretty big mistake inevitably kid"
# Predicted Label: pro-Palestine
# Score: 0.9037900567054749
# ----------------------------------------
# Text: "israel negotiate good faith peace gaza west bank package deal separate blockade colonise military solution mass murdering palestinian"
# Predicted Label: strongly pro-Palestine
# Score: 0.41855689883232117
# ----------------------------------------
# Text: "stroke watching soldier shoot tank she will counting girly quirky voice presenter acting complete pick bitch girl racial purist"
# Predicted Label: neutral
# Score: 0.7824364900588989
# ----------------------------------------
# Text: "nan"
# Predicted Label: neutral
# Score: 0.9870904088020325
# ----------------------------------------
# Text: "jewish people region year leave forgetting palestine offered multiple time refused prior israel independent state freedom governance jew"
# Predicted Label: pro-Israel
# Score: 0.9214553833007812
# ----------------------------------------
# Text: "captured loose weapon hamas frequently fight civilian clothes supposed enemy combatant"
# Predicted Label: strongly pro-Palestine
# Score: 0.8611552715301514
# ----------------------------------------
# Text: "nan"
# Predicted Label: neutral
# Score: 0.6119824647903442
# ----------------------------------------
# Text: "uploaded video posted channel check comment hope guy"
# Predicted Label: strongly pro-Israel
# Score: 0.7359728813171387
# ----------------------------------------
# Text: "hear anti russian terrorist kim jong nah zionist profile deny israel existence accuse netenyahu single evil people entire reality conflict interesting ultimately jew"
# Predicted Label: strongly pro-Palestine
# Score: 0.9558180570602417
# ----------------------------------------
# Text: "yup police acid literal nightmare fuel max ramp bad trip ultimate severe absolute complete maximum benzos hand tripping shut eventually called severely worst humanly imaginable"
# Predicted Label: strongly pro-Palestine
# Score: 0.9863107204437256
# ----------------------------------------
# Text: "amen"
# Predicted Label: pro-Israel
# Score: 0.9653416872024536
# ----------------------------------------
# Text: "gaza concentration camp"
# Predicted Label: pro-Palestine
# Score: 0.334949791431427
# ----------------------------------------
# Text: "bitten vaccine reasonable time issue"
# Predicted Label: strongly pro-Palestine
# Score: 0.5805965662002563
# ----------------------------------------
# Text: "pay bitch"
# Predicted Label: strongly pro-Palestine
# Score: 0.47273969650268555
# ----------------------------------------
# Text: "surprised israel lifetime nation weak order curtail expansionist colonies west"
# Predicted Label: strongly pro-Palestine
# Score: 0.6250460743904114
# ----------------------------------------
# Text: "european guy israel started gramps committed worst genocide human history hard decided british colony survivor kind leave pretty crazy modern israeli defended people sail kill shit member group experienced oppression millennia europe collectively ruin ancestor simply problem place destroyed coming agree gaza colonialism unapologetically benefit day calling righteously feel"
# Predicted Label: strongly pro-Palestine
# Score: 0.3944171667098999
# ----------------------------------------
# Text: "palestinian vacant mansion joke city rabbi west bank hope offer groans live"
# Predicted Label: neutral
# Score: 0.5040600299835205
# ----------------------------------------
